# %%
#conditional statements
#odd or even [if]

number=int(input("enter the value"))
if number%2==0:
    print("number is even")
# Out:
# enter the value 3

# %%
#positive, negative or zero [if & else}

number=int(input("enter the number"))
if number<0:
    print(f"(number) number is negative or zero")
else:
    print(f"(number) number is positive")
# Out:
# enter the number 9
# (number) number is positive

# %%
#positive, negative or zero [if,elif& else]

number=int(input("enter the number"))
if number<0:
    print(f"{number} number is negative")
elif number==0:
     print(f"{number} number is zero")
else:
    print(f"{number} number is positive")
# Out:
# enter the number 8
# 8 number is positive

# %%
#students marks nested conditional statements

marks=int(input("enter the marks"))
if marks>=90 and marks<=100:
    print("grade A")
elif marks>=80 and marks<=89:
    print("grade B")
elif marks>=70 and marks<=79:
    print("grade C")
elif marks>=60 and marks<=69:
    print("grade D")
else:
    print("invalid marks")
# Out:
# enter the marks 86
# grade B

# %%
# find the largest of two numbers

a=int(input("enter the value"))
b=int(input("enter the value"))
if a<b:
    print("b is greater")
else:
    print("a is greater")
# Out:
# enter the value 15
# enter the value 3
# a is greater

# %%
# person's age and eligibility to vote

age=int(input("enter the number"))
if age>=18:
    print("eligible to vote")
else:
    print("Not eligilble to vote")
# Out:
# enter the number 12
# Not eligilble to vote

# %%
# check number divisible by both 3 and 5

number=int(input("enter the value"))
if number%5==0 and number%3==0:
    print("divsible by both")
elif number%5==0:
    print("only divisible by 5")
else:
    print("only divsible by 3")
# Out:
# enter the value 15
# divsible by both

# %%
# leap year or not

number=int(input("enter the value"))
if number%4==0:
    print("it is a leap year")
else:
    print("it is not a leap year")
# Out:
# enter the value 2024
# it is a leap year

# %%
# check num positive[ yes---- check odd or even]
# num negative[ yes----- check absolute value is multipies of 5 or not]
# num zero[yes.....]

number=int(input("Enter the value"))
if number>0:
    print("positive")
    if number%2==0:
        print("even")
    else:
        print("odd")
elif number<0:
    if abs(number%5==0): #abosulate value is multiples of 5 or not
        print("Multiple of 5")
    else:
        print("not a multiple of 5")
else:
    print("zero is neithe positive or negative")
# Out:
# Enter the value 89
# positive
# odd

# %%
# username and password [both are correct as given... login sucess]
# username and password [user name correct password wrong... wrong password]
# username and password [both are wring--- user not found]

username=input("enter the username")
password= input("enter the password")
if username=="admin" and password=="admin123":
    print("login successful")
elif username=="admin" and pasword!="admin123":
    print("wrong password")
else:
    print("user not found")
# Out:
# enter the username ggg
# enter the password admin
# user not found

# %%
# Q the amt of withdraw( multiple of 10)
# the acc balance
# if the withdraw amt is multiple of 00 and lessthan or equal to balance, deduct the amt and print new balance
# otherwise give error message

account_balance=int(input("enter the account balance"))
withdraw_amountint(input("enter the withdraw amount"))
if withdraw_amount%100==0 and withdraw_amount<=account_balance:
    print("New balance:",account_balance-withdraw_amount,)
else:
    print("error")
# Out:
# enter the account balance 10000
# enter the withdraw amount 2000
# New balance: 8000
