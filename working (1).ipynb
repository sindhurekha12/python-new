# %%
#1.Create two variables and assign your name and age. Print them in a single sentence

name="sindhu"
age=20
print(f'My name is {name} and my age is {age}.')
# Out:
# My name is sindhu and my age is 20.

# %%
#2.Take two numbers as input from the user and print their sum, difference, product, and division

num1=int(input("Enter the number:"))
num2=int(input("enter the number:"))
print(num1+num2,num1-num2,num1*num2,num1/num2)
# Out:
# Enter the number: 20
# enter the number: 10
# 30 10 200 2.0

# %%
num1=int(input("Enter the first number:"))
num2=int(input("enter the second number:"))
print(f"sum:{num1+num2}")
print(f"Difference:{num1-num2}")
print(f"Product:{num1*num2}")
print(f"Division:{num1/num2}")
# Out:
# Enter the first number: 20
# enter the second number: 10
# sum:30
# Difference:10
# Product:200
# Division:2.0

# %%
#3.Create variables of different data types (int, float, string, bool) and print their types using type().

a=10
b=11.5
c="time"
d=True

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
#4.Swap two numbers using a third variable

num1 = 10
num2 = 20

print(f"Before swap: num1 = {num1}, num2 = {num2}")

# The swapping 

empty = num1
num1 = num2
num2 = empty

print(f"After swap: num1 = {num1}, num2 = {num2}")
num1=10
num2=20
# Out:
# Before swap: num1 = 10, num2 = 20
# After swap: num1 = 20, num2 = 10

# %%
#5.Swap two numbers without using a third variable.

num1=20
num2=30

num1=num1+num2
num2=num1-num2
num1=num1-num2

print(f"num1={num1},num2={num2}")
# Out:
# num1=30,num2=20

# %%
#6.Take a number as input and check whether it is even or odd using an if statement.

number=int(input("enter the value:"))
if number%2==0:
    print("The number is even")

else:
    print("The number is odd")
# Out:
# enter the value: 15
# The number is odd

# %%
#7.Take a string input and print it in uppercase and lowercase.

name=input("Enter the name:")

print(f"uppercase:{name.upper()}")
print(f"lowercase:{name.lower()}")
# Out:
# Enter the name: samhitha vignesh
# uppercase:SAMHITHA VIGNESH
# lowercase:samhitha vignesh

# %%
#8.Count the number of characters in a string using len().

text="samhitha"
length=len(text)

print(length)
# Out:
# 8

# %%
#9.Convert a string '123' into an integer and multiply it by 5.

s='123'
s1=int(s)
print(s1*5)
# Out:
# 615

# %%
#10.Take user input (age) and check if the person is eligible to vote (18+).

age=int(input("Enter the number:"))
if age>=18:
    print(f"Eligible")
else:
    print(f"Not Eligible")
# Out:
# Enter the number: 23
# Eligible

# %%
# 11. Perform all arithmetic operations on two user-input numbers.


num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))

print(f"Addition: {num1 + num2}")
print(f"Subtraction: {num1 - num2}")
print(f"Multiplication: {num1 * num2}")
print(f"Division: {num1 / num2}")
print(f"Floor Division: {num1 // num2}")
print(f"Exponentiation: {num1 ** num2}")
print(f"Modulus: {num1 % num2}")
# Out:
# Enter the first number:  10
# Enter the second number:  20
# Addition: 30
# Subtraction: -10
# Multiplication: 200
# Division: 0.5
# Floor Division: 0
# Exponentiation: 100000000000000000000
# Modulus: 10

# %%
# 12. Check whether a given character is a vowel or consonant.

char = input("Enter a character: ")

vowels = ['a', 'e', 'i', 'o', 'u']

if char in vowels:              #(in) keyword
    print(f"{char} is a vowel")
else:
    print(f"{char} is a consonant")
# Out:
# Enter a character:  c
# c is a consonant

# %%
# 13. Create a list of 5 numbers and print the largest number using max().

list1 = [874, 345, 765, 987, 387]
print(list1)

largest = max(list1)
print(f"The largest number is: {largest}")
# Out:
# [874, 345, 765, 987, 387]
# The largest number is: 987

# %%
# 14. Add an element to a list and remove one element from it.

list1 = [12, 34, 65, 78, 10.24, 'hi', 'hello', 10, 14]

# Add an element
list1.append(23)
print("After adding 23:", list1)

# Remove an element
list1.remove('hi')
print("After removing 'hi':", list1)
# Out:
# After adding 23: [12, 34, 65, 78, 10.24, 'hi', 'hello', 10, 14, 23]
# After removing 'hi': [12, 34, 65, 78, 10.24, 'hello', 10, 14, 23]

# %%
# 15. Create a tuple with 5 elements and print its length.
tup = (56, 67, 89, 'his', 90)
length = len(tup)

print(f"Tuple: {tup}")
print(f"Length: {length}")
# Out:
# Tuple: (56, 67, 89, 'his', 90)
# Length: 5

# %%
#16. Create a dictionary with keys: name, age, city. Print each value separately.

details={'name':'sam','age':9,'city':'chennai'}
print(details['name'])
print(details['age'])
print(details['city'])
# Out:
# sam
# 9
# chennai

# %%
#17.Convert an integer into float and print both values with their types.

number=23
x=float(number)
print(number,type(number))
print(x,type(x))
# Out:
# 23 <class 'int'>
# 23.0 <class 'float'>

# %%
# 18. Take a sentence as input and replace a word with another word.

s = input("Enter a sentence: ")                                        
s1 = s.replace("beautiful", "awesome")

print(s1)
# Out:
# Enter a sentence:  The nauture is beautiful
# The nauture is awesome

# %%
#19.Check if a given string starts with a specific letter using startswith().

str1=("sam is good")
result=str1.startswith('s')
print(f" string:{str1})
print
# Out:
# sam is good

# %%
#20.Create a set with duplicate values and observe the output.

set1={23,56,89,45,90,67,34,45,23}
print(set1)   # not allows duplicate values
# Out:
# {34, 67, 23, 56, 89, 90, 45}

# %%
#21.Take a number and check whether it is positive, negative, or zero.

num=int(input("Enter the number:"))
if num > 0:
    print("The number is positive.")
elif num < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# Enter the number: 5
# The number is positive.

# %%
#.22 Create two numbers and compare them using comparison operators.

num1=(20,30,40,50,60)
num2=(25,35,45,55,65)
x=num1<=num2
print(x)
# Out:
# True
