# %%
fruits=["apple","banana","cherry","guva","pomegranate","apple"]

# %%
#adding one element to the list.
fruits.append("banana")
fruits
# Out:
# ['apple', 'banana', 'cherry', 'guva', 'pomegranate', 'apple', 'banana']

# %%
fruits.sort(reverse=True)

# %%
fruits
# Out:
# ['pomegranate', 'guva', 'cherry', 'banana', 'banana', 'apple', 'apple']

# %%
#adding multiple element

fruits.extend(["carrot","beetroot",50])

# %%
fruits
# Out:
# ['pomegranate',
#  'guva',
#  'cherry',
#  'banana',
#  'banana',
#  'apple',
#  'apple',
#  'carrot',
#  'beetroot',
#  50]

# %%
fruits.insert(0,"welcome")

# %%
fruits
# Out:
# ['welcome',
#  'pomegranate',
#  'guva',
#  'cherry',
#  'banana',
#  'banana',
#  'apple',
#  'apple',
#  'carrot',
#  'beetroot',
#  50]

# %%
fruits.remove("welcome")

# %%
fruits
# Out:
# ['pomegranate',
#  'guva',
#  'cherry',
#  'banana',
#  'banana',
#  'apple',
#  'apple',
#  'carrot',
#  'beetroot',
#  50]

# %%
fruits.pop()
# Out:
# 50

# %%
fruits
# Out:
# ['pomegranate',
#  'guva',
#  'cherry',
#  'banana',
#  'banana',
#  'apple',
#  'apple',
#  'carrot',
#  'beetroot']

# %%
fruits.pop(1)
# Out:
# 'guva'

# %%
fruits
# Out:
# ['pomegranate',
#  'cherry',
#  'banana',
#  'banana',
#  'apple',
#  'apple',
#  'carrot',
#  'beetroot']

# %%
fruits.index("carrot")
# Out:
# 6

# %%
f1=fruits.copy()

# %%
f1
# Out:
# ['pomegranate',
#  'cherry',
#  'banana',
#  'banana',
#  'apple',
#  'apple',
#  'carrot',
#  'beetroot']

# %%
fruits.clear()

# %%
fruits
# Out:
# []

# %%
f1
# Out:
# ['pomegranate',
#  'cherry',
#  'banana',
#  'banana',
#  'apple',
#  'apple',
#  'carrot',
#  'beetroot']

# %%
f1.count("apple")
# Out:
# 2

# %%
f1.reverse()

# %%
f1
# Out:
# ['beetroot',
#  'carrot',
#  'apple',
#  'apple',
#  'banana',
#  'banana',
#  'cherry',
#  'pomegranate']

# %%
len(f1)
# Out:
# 8

# %%
f2=[10,900,89,89,90,78,89]
f2.sort(reverse=True)

# %%
f2
# Out:
# [900, 90, 89, 89, 89, 78, 10]

# %%
min(f2)
# Out:
# 10

# %%
max(f2)
# Out:
# 900

# %%
sum(f2)
# Out:
# 1345

# %%
#tuple------->ordered,duplicates allowed, indexing and slicing supported,we can store differnet data types,
but its immutable,used to store (),

# %%
tuple1=("apple","banana","cherry",["carrot","beetroot","gabbage"],[89,90,89],"mango")

# %%
tuple1
# Out:
# ('apple',
#  'banana',
#  'cherry',
#  ['carrot', 'beetroot', 'gabbage'],
#  [89, 90, 89],
#  'mango')

# %%
tuple1[-3][2]
# Out:
# 'gabbage'

# %%
tuple1.count("apple")
# Out:
# 1

# %%
tuple1.index("mango")
# Out:
# 5

# %%
t1=list(tuple1)

# %%
t1
# Out:
# ['apple',
#  'banana',
#  'cherry',
#  ['carrot', 'beetroot', 'gabbage'],
#  [89, 90, 89],
#  'mango']

# %%
print("apple" in tuple1)
# Out:
# True

# %%
#sets------->To store unique elements,unordered,duplicates not allowed,partially mutable,parenthesis, set()

set1={10,90,"sri","priya","sri",(90,90,89)}

# %%
set1
# Out:
# {(90, 90, 89), 10, 90, 'priya', 'sri'}

# %%
s2={}

# %%
type(s2)
# Out:
# dict

# %%
s1=set()

type(s1)
# Out:
# set

# %%
s1.add("apple")

s1
# Out:
# {'apple'}

# %%
s1.update(["banana","cherry","guva"])

s1
# Out:
# {'apple', 'banana', 'cherry', 'guva'}

# %%
s3=s1.copy()

s3
# Out:
# {'apple', 'banana', 'cherry', 'guva'}

# %%
s3.remove("apple")

s3
# Out:
# {'banana', 'cherry', 'guva'}

# %%
s3.pop()

s3
# Out:
# {'banana'}

# %%
s3.discard("a")

s3
# Out:
# {'banana'}

# %%
s1={1,2,3}
s2={3,4,5}

s1.union(s2)
# Out:
# {1, 2, 3, 4, 5}

# %%
s1.intersection(s2)
# Out:
# {3}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 2, 4, 5}

# %%
s1.difference(s2)
# Out:
# {1, 2}

# %%
s2.difference(s1)
# Out:
# {4, 5}

# %%
s3={1,2,3}
s4={1,2,3,4,5}
s3.issubset(s4)
# Out:
# True

# %%
s3.issuperset(s4)
# Out:
# False

# %%
s3.isdisjoint(s4)
# Out:
# False

# %%
set1={1,2,3}
set2={4,5,6}
set1.isdisjoint(set2)
# Out:
# True

# %%
s1={1,2,3}
s2={3,4,5}

s1.intersection_update(s2)

# %%
s1
# Out:
# {3}

# %%
s1={1,2,3}
s2={3,4,5}
s1.intersection(s2)
# Out:
# {3}

# %%
s1
# Out:
# {1, 2, 3}

# %%
#dictionary------->store key,value pairs, its mutable,keys must  be unique but values 
#can be duplicates,{ }

# %%
student={"name":"sri","age":20,"city":"coimbatore"}

type(student)
# Out:
# dict

# %%
d1=dict(name="priya",age=25)
d1
# Out:
# {'name': 'priya', 'age': 25}

# %%
student
# Out:
# {'name': 'sri', 'age': 20, 'city': 'coimbatore'}

# %%
student["name"]
# Out:
# 'sri'

# %%
student["name"]="sindhu"

student
# Out:
# {'name': 'sindhu', 'age': 20, 'city': 'coimbatore'}

# %%
student["course"]="Ai"

student
# Out:
# {'name': 'sindhu', 'age': 20, 'city': 'coimbatore', 'course': 'Ai'}

# %%
student.get("name","notfound")
# Out:
# 'sindhu'

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'city', 'course'])

# %%
student.values()
# Out:
# dict_values(['sindhu', 20, 'coimbatore', 'Ai'])

# %%
student.items()
# Out:
# dict_items([('name', 'sindhu'), ('age', 20), ('city', 'coimbatore'), ('course', 'Ai')])

# %%
student.pop("age")
# Out:
# 20

# %%
student
# Out:
# {'name': 'sindhu', 'city': 'coimbatore', 'course': 'Ai'}

# %%
del student["city"]

student
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 del student["city"]
#       2
#       3 student
#
# KeyError: 'city'

# %%
student={"name":"sri","age":20,"city":"coimbatore"}

# %%
student.popitem()
# Out:
# ('city', 'coimbatore')

# %%
list1=["name","age","address"]
d1=dict.fromkeys(list1,"unknown")
d1
# Out:
# {'name': 'unknown', 'age': 'unknown', 'address': 'unknown'}

# %%
key=['a','b','c']
value=0
pair=dict.fromkeys(key,value)
pair
# Out:
# {'a': 0, 'b': 0, 'c': 0}

# %%
d1={"name":"sri","age":23}
d2={"city":"coimbatore","age":25}
d1.update(d2)

# %%
d1
# Out:
# {'name': 'sri', 'age': 25, 'city': 'coimbatore'}

# %%
d2.update(d1)

d2
# Out:
# {'city': 'coimbatore', 'age': 25, 'name': 'sri'}

# %%
data={"name":"priya","nickname":"sri","age":25,"city":"coimbatore"}


data.setdefault("age",37)
# Out:
# 25
